# %%
from sdv import Metadata
from pathlib import Path
from sampqle.synthesize import get_expanded_data

# %%
data_folder = Path.cwd().parent / "data"

# %%
meta = Metadata(str(data_folder / "meta.json"))

meta.visualize()

# %%
results = get_expanded_data(data_folder=data_folder)

# %%
for k, v in results.items():
    print(f"{k} - {len(v)}")
# Out:
# users - 1000
# profiles - 815
# nps - 8374
# sessions - 28873
# transactions - 45796
# products - 25
